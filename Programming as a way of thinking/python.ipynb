# %% [markdown]
# # Arithmetic operators

# %% [markdown]
# These are symbols that represent an arithmetic computation.  For example, the + performs addition

# %% [markdown]
# 55 + 12

# %% [markdown]
# # The - sign is for subtraction
# 79 - 12

# %% [markdown]
# # The * sign is to perform multiplication
# 6 * 7

# %% [markdown]
# # The / symbol is used for division

# %% [markdown]
# ### When you divide in Python, the answer will aways be a data type called a float.

# %% [markdown]
# ## Integer - Represents numbers with no fractional or decimal part

# %% [markdown]
# ### Floating-point numbers - represent numbers with a decimal or fractional value

# %% [markdown]
# # The // symbol stands for Floor Division (Integer Division)

# %% [markdown]
# ### Floor Division gives you everything before the decimal

# %%
85 / 2
# Out:
# 42

# %%
85 // 2
# Everything from the decimal on gets removed from our answer.

# %%
# The ** symbol is used to represent exponents
7 ** 2
# Out:
# 49

# %%
10 ** -325
# Out:
# 0.0

# %%
10 ** 325
# Out:
# 

# %%
# The ^ symbol (the carrt)  , in Python it is a bitwise operator called XOR

# %%
# The % Symbol is used for what we Modulus Division

85 % 2
# Out:
# 1

# %% [markdown]
# ## 1.2 Expressions

# %% [markdown]
# Expression - A collection of operators and numbers is called an expression
#
# example:
# 6 + 6 ** 2
# 12 ** 2
# 42
#
# (12+ 5) * 6
# 17 * 6
# 102
#
# 12 + 5 * 6
# 12 + 30
# 42
#
# myVar = var1 * var2 + var3
#
# ## 1.3 Arithmetic functions

# %% [markdown]
# Python is a modular language:
# * Core Python code
# * Extxternal Modules - imported into scripts
# import math
#
# Python like any programming language has built-functions
# round(42.4)
#
# round () - this function takes a floating-point number and rounds it off to the nearest integer

# %%
round(42.4)
# Out:
# 42

# %%
round(42.6)
# Out:
# 43

# %% [markdown]
# abs() function - computes the absolute value of a number

# %%
abs (42)
# Out:
# 42

# %%
abs(-42)
# Out:
# 42

# %% [markdown]
# ### Calling a function

# %% [markdown]
# The process of using a function within your code
#
# WHenever you call a function, the parathesis are required!!

# %%
abs 42
# Out:
#   Cell In[7], line 1
#     abs 42
#         ^
# SyntaxError: invalid syntax

# %%
abs
# Out:
# <function abs(x, /)>

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round (3.1415, 2)
# Out:
# 3.14

# %% [markdown]
# ### 1.4 Strings

# %% [markdown]
# A string is a sequence of characters that are delimited by quotation marks ( either single ro doubt doesnt matter as long as they match).
#
# myStr = "This is my string#^!!04&9"

# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
"it's a small world"
# Out:
# "it's a small world"

# %%
# The escape character ] - This tells the interpreter to not process the next character
'It\'s a small world'
# Out:
# "It's a small world"

# %%
#concationation symbol + - The + sign concatinates (connects together) # two strings

"well, " + "it's a small world" + "after all."
# Out:
# "well, it's a small worldafter all."

# %% [markdown]
# ### Strings and the * operator

# %% [markdown]
# The * operator works with strings by making copies of a string and concatenates them together.

# %%
"Spam, " * 4
# Out:
# 'Spam, Spam, Spam, Spam, '

# %% [markdown]
# ### strings and len() function

# %%
len("Spam")
# Out:
# 4

# %% [markdown]
# ### 1.5 Values and Types

# %%
# type () function - Python will tell you what type of data something is 

type(42)
# Out:
# int

# %%
type(42.)
# Out:
# float

# %%
# int() function - changes a valid floating-point number to an integer

int(42.5)
# Out:
# 42

# %%
# float () function - changes a valid integer to a floating point number

float(42)
# Out:
# 42.0

# %%
'126'
# Out:
# '126'

# %%
type("126")
# Out:
# str

# %%
int("126") / 3
# Out:
# 42.0

# %%
float(12.6) * 3
# Out:
# 37.8

# %%
1,000,000 * 5
# Out:
# (1, 0, 0)

# %%
1000000 * 5
# Out:
# 5000000

# %%
1_000_000 * 5
# Out:
# 5000000

# %% [markdown]
# ### Natural Language
#
# Are languages people speak, like English, Spanish, and French etc.  They were not technically designed by people, naturally evolved from human speach.

# %% [markdown]
# ### Formal Language
#
# Are languages that are designed by people for specific applications.  For example, the notation that mathmaticians use a formal language that is particularly good at denoting relationships among numbers and symbols.

# %% [markdown]
# ### Debugging
#
# Mistakes made in the process of programming have been come to be known as bugs.  Tracking down and fixing those mistakes then became debugging.
